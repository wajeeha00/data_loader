# %%
from IPython.display import display, HTML

# %%
from sqlalchemy.orm import sessionmaker
from sqlalchemy import MetaData, Table
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Date, ForeignKey
from sqlalchemy.orm import relationship
from sqlalchemy import create_engine, and_
from sqlalchemy.orm import sessionmaker
import pandas as pd
import logging

# %%
engine = create_engine('mssql+pyodbc://curemd:cure2000@CMDLHRLDT01\SQL2K22/TwoPracticeMedical?driver=ODBC+Driver+17+for+SQL+Server')


# Bind the session
Session = sessionmaker(bind=engine)
session = Session()
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


from sqlalchemy import create_engine, and_
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd
import logging

# Initialize logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Create engine
engine = create_engine('mssql+pyodbc://curemd:cure2000@CMDLHRLDT01\SQL2K22/TwoPracticeMedical?driver=ODBC+Driver+17+for+SQL+Server')

# Initialize the sessionmaker
Session = sessionmaker(bind=engine)

# Base class for ORM models
Base = declarative_base()
# Out:
# C:\Users\wajeeha.aftab\AppData\Local\Temp\ipykernel_21680\3266549299.py:28: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
class Vitals(Base):
    __tablename__ = 'Vitals'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')  
    Practice = Column(String)
    vSoapText = Column(String)
    VitalsID = Column(Integer, name='Vitals ID')  
    date = Column(Date, name='Date / Time')

class DiseasesMedicalHistory(Base):
    __tablename__ = 'DiseasesMedicalHistory'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')  # Correcting column name with space
    Practice = Column(String)
    vSoapText = Column(String)
   
class Allergies(Base):
    __tablename__ = 'Allergies'
    iReportID = Column(Integer, name='ireportId', primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String)
    vSoapText = Column(String)

class FamilyHistory(Base):
    __tablename__ = 'FamilyHistory'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String, name='Practice Name')
    vSoapText = Column(String)

class LabOrders(Base):
    __tablename__ = 'LabOrders'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String)
    Practice = Column(String)

class OBGYNHistory(Base):
    __tablename__ = 'OBGYNHistory'
    iReportID = Column(Integer, name='ireportid', primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String, name='Practice Name')
    vSoapText = Column(String)

# class PhysicalExam(Base):
#     __tablename__ = 'PhysicalExam'
#     iReportID = Column(Integer, primary_key=True)
#     # Patient_ID = Column(Integer, name='VAccNo') NO PATIENTID
#     Practice = Column(String, name='PracticeName')
#     vSoapText = Column(String)

class SocialHistory(Base):
    __tablename__ = 'SocialHistory'
    iReportID = Column(Integer, name='ireportid',  primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    vSoapText = Column(String)
    Practice = Column(String, name='PracticeName')

class SurgeryHistory(Base):
    __tablename__ = 'SurgeryHistory'
    iReportID = Column(Integer, name='IreportID', primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String, name='PracticeName')
    vSoapText = Column(String)

# %%
# Create engine

query = session.query(
    Vitals.Practice,
    Vitals.Patient_ID,
    Vitals.iReportID,
    Vitals.vSoapText.label('Vitals_vSoapText'),
    Vitals.date,
    Vitals.VitalsID,
    DiseasesMedicalHistory.vSoapText.label('Disease_vSoapText'),
).join(
    DiseasesMedicalHistory,
    and_(
        Vitals.Practice == DiseasesMedicalHistory.Practice,
        Vitals.Patient_ID == DiseasesMedicalHistory.Patient_ID,
        Vitals.iReportID == DiseasesMedicalHistory.iReportID
    ),
    isouter=True  # This ensures it's a left join from the perspective of Vitals
)

# %%
result1 = query.all()  # Execute the query
data = [result._asdict() for result in result1]  # Convert results to list of dictionaries
df = pd.DataFrame(data)  # Create DataFrame from the data

print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %%
#print columns
print(df.columns)
# Out:
# Index(['Practice', 'Patient_ID', 'iReportID', 'Vitals_vSoapText', 'date',
#        'VitalsID', 'Disease_vSoapText'],
#       dtype='object')

# %%
#remove Patient_ID, Practice, and iReportID duplicates by keeping latest vitalsID
df = df.sort_values('VitalsID').drop_duplicates(['Patient_ID', 'Practice', 'iReportID'], keep='last')

# %%
class Vitals(Base):
    __tablename__ = 'Vitals'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')  
    Practice = Column(String)
    vSoapText = Column(String)
    VitalsID = Column(Integer, name='Vitals ID')  
    date = Column(Date, name='Date / Time')

class DiseasesMedicalHistory(Base):
    __tablename__ = 'DiseasesMedicalHistory'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')  # Correcting column name with space
    Practice = Column(String)
    vSoapText = Column(String)
   
class Allergies(Base):
    __tablename__ = 'Allergies'
    iReportID = Column(Integer, name='ireportId', primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String)
    vSoapText = Column(String)

class FamilyHistory(Base):
    __tablename__ = 'FamilyHistory'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String, name='Practice Name')
    vSoapText = Column(String)

class LabOrders(Base):
    __tablename__ = 'LabOrders'
    iReportID = Column(Integer, primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String)
    Practice = Column(String)

class OBGYNHistory(Base):
    __tablename__ = 'OBGYNHistory'
    iReportID = Column(Integer, name='ireportid', primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String, name='Practice Name')
    vSoapText = Column(String)

# class PhysicalExam(Base):
#     __tablename__ = 'PhysicalExam'
#     iReportID = Column(Integer, primary_key=True)
#     # Patient_ID = Column(Integer, name='VAccNo') NO PATIENTID
#     Practice = Column(String, name='PracticeName')
#     vSoapText = Column(String)

class SocialHistory(Base):
    __tablename__ = 'SocialHistory'
    iReportID = Column(Integer, name='ireportid',  primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    vSoapText = Column(String)
    Practice = Column(String, name='PracticeName')

class SurgeryHistory(Base):
    __tablename__ = 'SurgeryHistory'
    iReportID = Column(Integer, name='IreportID', primary_key=True)
    Patient_ID = Column(Integer, name='Patient ID')
    Practice = Column(String, name='PracticeName')
    vSoapText = Column(String)
# Out:
# C:\Users\wajeeha.aftab\AppData\Local\Temp\ipykernel_18800\4016380528.py:1: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
query = session.query(
    Vitals.Practice,
    Vitals.Patient_ID,
    Vitals.iReportID,
    Vitals.vSoapText.label('Vitals_vSoapText'),
    Vitals.date,
    Vitals.VitalsID,
    DiseasesMedicalHistory.vSoapText.label('Disease_vSoapText')
).join(
    DiseasesMedicalHistory,
    and_(
        Vitals.Practice == DiseasesMedicalHistory.Practice,
        Vitals.Patient_ID == DiseasesMedicalHistory.Patient_ID,
        Vitals.iReportID == DiseasesMedicalHistory.iReportID
    ),
    isouter=True
)

# %%
result1 = query.all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %%
Session = sessionmaker(bind=engine)
session = Session()

query = session.query(
    Vitals.Practice,
    Vitals.Patient_ID,
    Vitals.iReportID,
    Vitals.vSoapText.label('Vitals_vSoapText'),
    Vitals.date,
    Vitals.VitalsID,
    DiseasesMedicalHistory.vSoapText.label('Disease_vSoapText'),
    Allergies.vSoapText.label('Allergies_vSoapText'),
    FamilyHistory.vSoapText.label('FamilyHistory_vSoapText'),
    OBGYNHistory.vSoapText.label('OBGYNHistory_vSoapText'),
    SocialHistory.vSoapText.label('SocialHistory_vSoapText'),
    SurgeryHistory.vSoapText.label('SurgeryHistory_vSoapText')
).join(
    DiseasesMedicalHistory,
    and_(
        Vitals.Practice == DiseasesMedicalHistory.Practice,
        Vitals.Patient_ID == DiseasesMedicalHistory.Patient_ID,
        Vitals.iReportID == DiseasesMedicalHistory.iReportID
    ),
    isouter=True
).join(
    Allergies,
    and_(
        Vitals.Practice == Allergies.Practice,
        Vitals.Patient_ID == Allergies.Patient_ID,
        Vitals.iReportID == Allergies.iReportID
    ),
    isouter=True
).join(
    FamilyHistory,
    and_(
        Vitals.Practice == FamilyHistory.Practice,
        Vitals.Patient_ID == FamilyHistory.Patient_ID,
        Vitals.iReportID == FamilyHistory.iReportID
    ),
    isouter=True
).join(
    OBGYNHistory,
    and_(
        Vitals.Practice == OBGYNHistory.Practice,
        Vitals.Patient_ID == OBGYNHistory.Patient_ID,
        Vitals.iReportID == OBGYNHistory.iReportID
    ),
    isouter=True
).join(
    SocialHistory,
    and_(
        Vitals.Practice == SocialHistory.Practice,
        Vitals.Patient_ID == SocialHistory.Patient_ID,
        Vitals.iReportID == SocialHistory.iReportID
    ),
    isouter=True
).join(
    SurgeryHistory,
    and_(
        Vitals.Practice == SurgeryHistory.Practice,
        Vitals.Patient_ID == SurgeryHistory.Patient_ID,
        Vitals.iReportID == SurgeryHistory.iReportID
    ),
    isouter=True
)

# %%
# Execute the query
results = query.all()

# %%
# First Query: Vitals with DiseasesMedicalHistory, Allergies, and FamilyHistory
query1 = session.query(
    Vitals.Practice,
    Vitals.Patient_ID,
    Vitals.iReportID,
    Vitals.vSoapText.label('Vitals_vSoapText'),
    Vitals.date,
    Vitals.VitalsID,
    DiseasesMedicalHistory.vSoapText.label('Disease_vSoapText'),
    Allergies.vSoapText.label('Allergies_vSoapText'),
    FamilyHistory.vSoapText.label('FamilyHistory_vSoapText')
).outerjoin(
    DiseasesMedicalHistory,
    and_(
        Vitals.Practice == DiseasesMedicalHistory.Practice,
        Vitals.Patient_ID == DiseasesMedicalHistory.Patient_ID,
        Vitals.iReportID == DiseasesMedicalHistory.iReportID
    )
).outerjoin(
    Allergies,
    and_(
        Vitals.Practice == Allergies.Practice,
        Vitals.Patient_ID == Allergies.Patient_ID,
        Vitals.iReportID == Allergies.iReportID
    )
).outerjoin(
    FamilyHistory,
    and_(
        Vitals.Practice == FamilyHistory.Practice,
        Vitals.Patient_ID == FamilyHistory.Patient_ID,
        Vitals.iReportID == FamilyHistory.iReportID
    )
)

# Execute Query 1 and fetch results
results1 = query1.all()

# %%
# Second Query: Vitals with OBGYNHistory, SocialHistory, and SurgeryHistory
query2 = session.query(
    Vitals.Practice,
    Vitals.Patient_ID,
    Vitals.iReportID,
    OBGYNHistory.vSoapText.label('OBGYNHistory_vSoapText'),
    SocialHistory.vSoapText.label('SocialHistory_vSoapText'),
    SurgeryHistory.vSoapText.label('SurgeryHistory_vSoapText')
).outerjoin(
    OBGYNHistory,
    and_(
        Vitals.Practice == OBGYNHistory.Practice,
        Vitals.Patient_ID == OBGYNHistory.Patient_ID,
        Vitals.iReportID == OBGYNHistory.iReportID
    )
).outerjoin(
    SocialHistory,
    and_(
        Vitals.Practice == SocialHistory.Practice,
        Vitals.Patient_ID == SocialHistory.Patient_ID,
        Vitals.iReportID == SocialHistory.iReportID
    )
).outerjoin(
    SurgeryHistory,
    and_(
        Vitals.Practice == SurgeryHistory.Practice,
        Vitals.Patient_ID == SurgeryHistory.Patient_ID,
        Vitals.iReportID == SurgeryHistory.iReportID
    )
)

# Execute Query 2 and fetch results
results2 = query2.all()

# %%
# Out:
# ERROR:__main__:An error occurred: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC Driver 17 for SQL Server]TCP Provider: Timeout error [258].  (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Unable to complete login process due to delay in prelogin response (258)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ERROR:__main__:Failed to process data: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC Driver 17 for SQL Server]TCP Provider: Timeout error [258].  (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Unable to complete login process due to delay in prelogin response (258)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

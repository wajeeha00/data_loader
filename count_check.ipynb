# %%
from pymongo import MongoClient
import pandas as pd
# Using environment variables for credentials
mongo_uri = f"mongodb://bootcamp24:Bootcamp%232024@172.16.101.226:27017/?authMechanism=DEFAULT"
 
# Create MongoDB client
client = MongoClient(mongo_uri)
db = client['Capstone_2024']
collection = db['ProviderNotesDiagnosis_NC']
projection = {  
    "PatientID": 1, 
    "Practice": 1,
    "NoteID":1,
    
    "SOAPTEXT": 1 ,
    "DiagnosisCodes": 1,
    "Notetype": 1,
    "NoteTemplate":1,


    }
data = pd.DataFrame(list(    collection.find(filter={}, projection=projection, limit=100000)))

# %%
#need to find occurences on the basis of notetype and note template
data['NoteTemplate'].value_counts()
# Out:
# NoteTemplate
# Phone Encounter                   6636
# Immunization Note                 5296
# Gen Clinic                        2973
# Lab Only                          2482
# a CPC Return Patient Note         2288
#                                   ...
# ED/Hospital Follow-up Note           1
# FP Male                              1
# POSSE                                1
# FP Nexplanon Removal/Insertion       1
# BF - Well Child 1 Month - WCHD       1
# Name: count, Length: 1386, dtype: int64

# %%
data['Notetype'].value_counts()
# Out:
# Notetype
# Progress Note      72293
# Phone Encounter     9900
# Admit Note          6229
# FP History          1266
# H&P Note            1233
#                    ...
# Referral               1
# Note                   1
# CDL Physical           1
# BCCP Follow Up         1
# BCCCP Visit            1
# Name: count, Length: 152, dtype: int64

# %%
from IPython.display import HTML, display

# %%
grouped_data = data.groupby(['Notetype', 'NoteTemplate']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)

# %%
grouped_data.head(10)
# Out:
#              Notetype               NoteTemplate  counts
# 417   Phone Encounter            Phone Encounter    6332
# 972     Progress Note          Immunization Note    5084
# 924     Progress Note                 Gen Clinic    2973
# 996     Progress Note                   Lab Only    2482
# 1422    Progress Note  a CPC Return Patient Note    2287
# 423   Phone Encounter           Phone Encounter2    1805
# 1297    Progress Note               TB Skin Test    1520
# 1335    Progress Note                    WIC Lab    1318
# 116        Admit Note     SCHD A Blank SOAP NOTE    1258
# 1231    Progress Note  STD Encounter - Form 2808    1158

# %%
df1 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'Gen Clinic')]

# %%
storage ={}

# %%
storage["Progress Note"] = "a CPC Return Patient Note"

# %%
storage
# Out:
# {'Progress Note': 'a CPC Return Patient Note'}

# %%
not_type = []
not_type.append("Phone Encounter")

# %%
not_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 not_type
#
# NameError: name 'not_type' is not defined

# %%
not_template = []
not_template.append("Immunization Note")

# %%
not_template
# Out:
# ['Immunization Note']

# %%
df1.sample(5)
# Out:
#                             _id                            Practice  \
# 23379  6752e1a7387f4a204286f95a  Albemarle Regional Health Services
# 7688   6752e1a660577172a05e2c39  Albemarle Regional Health Services
# 14458  6752e1a860577172a05e3ea6  Albemarle Regional Health Services
# 39245  6752e1ab387f4a2042871d54  Albemarle Regional Health Services
# 12657  6752e1a3387f4a204286d378  Albemarle Regional Health Services
#
#        PatientID  NoteID       Notetype NoteTemplate  \
# 23379      81658   22711  Progress Note   Gen Clinic
# 7688      104730  153284  Progress Note   Gen Clinic
# 14458      59330  259015  Progress Note   Gen Clinic
# 39245     177361  293020  Progress Note   Gen Clinic
# 12657      66231  280476  Progress Note   Gen Clinic
#
#                                                 SOAPTEXT DiagnosisCodes
# 23379  <P align=center><STRONG>GENERAL CLINIC</STRONG...            NaN
# 7688   <P align=center><STRONG>GENERAL CLINIC</STRONG...            Z23
# ...

# %%
display(HTML(df1.iloc[0]['SOAPTEXT']))
# Out:
# <P align=center><STRONG>GENERAL CLINIC</STRONG></P>
# <P>&nbsp;</P>
# <P><STRONG>Patient Name: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~24018 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§"></LABEL>, <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~24019 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§"></LABEL></STRONG></P>
# ...

# %%
display(HTML(df1.iloc[5]['SOAPTEXT']))
# Out:
# <P align=center><STRONG>GENERAL CLINIC</STRONG></P>
# <P>&nbsp;</P>
# <P><STRONG>Patient Name: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~24018 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§"></LABEL>, <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~24019 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§"></LABEL></STRONG></P>
# ...

# %%
display(HTML(df1.iloc[8]['SOAPTEXT']))
# Out:
# <P align=center><STRONG>GENERAL CLINIC</STRONG></P>
# <P>&nbsp;</P>
# <P><STRONG>Patient Name: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~24018 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§"></LABEL>, <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~24019 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§"></LABEL></STRONG></P>
# ...

# %%
df2 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'Lab Only')]

# %%
display(HTML(df2.iloc[15]['SOAPTEXT']))
# Out:
# <P><LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~21521 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§" j="§" jQuery17204333975886155446="69"></LABEL>&nbsp;&nbsp;&nbsp; <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~21522 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§" j="§" jQuery17204333975886155446="70"></LABEL></P>
# ...

# %%
display(HTML(df2.iloc[70]['SOAPTEXT']))
# Out:
# <p></p><div onclick=clearSelection() ondblclick="OnBtn('btn~~1147098s7','../../Order_Result/Lab/datLab.asp?')" onresizestart="return false;" onmousedown="onmouserightclick('btn~~1147098s7')" id=btn~~1147098s7 class=btnComponent_Attached contentEditable=false style="CURSOR: pointer; WIDTH: 100%" unselectable="on" intComponentRecID="108762" iCompID="898621">
# <TABLE class=tblButton cellSpacing=0 cellPadding=0 width="100%" border=0>
# <TBODY>
# <TR>
# <TD align=left><FONT id=Comp_Heading class=Comp_Heading_Attached face=arial>Lab Order:</FONT></TD></TR>
# <TR id=traDetail class=traDetail_Attached>
# ...

# %%
display(HTML(df2.iloc[579]['SOAPTEXT']))
# Out:
# <P>&nbsp;</P><B>Lab Order</B><BR>04/16/2020<BR>COVID 19 NAA(CPT-87635)<I> [Nose (nasal passage)]</I><BR>
# <P>&nbsp;</P><B>Diagnoses</B><BR><U>Encounter for observation for suspected exposure to other biological agents ruled out</U> - Z03.818<BR>
# <P>&nbsp;</P><B>Procedures</B><BR>HANDLG&amp;/OR CONVEY OF SPEC FOR TR OFFICE TO LAB (CPT-99000), Units: 1.<BR>2019 Novel Coronavirus Diagnostic Test Panel SARS-CoV2/2019-nCoV. (CPT-U0002), Units: 1.<BR>2019 Novel Coronavirus Diagnostic Test Panel (CPT-U0001), Units: 1.<BR>
# <P>&nbsp;</P><BR><BR><font style='font-family:arial;font-size:10pt;color:green'>Electronically signed by Edwards, Kristine , RN. on Thursday, April 16, 2020 at 11:33 AM</font>

# %%
display(HTML(df2.iloc[871]['SOAPTEXT']))
# Out:
# <P>&nbsp;</P><B>Lab Order</B><BR>07/06/2020<BR>COVID 19 NAA(CPT-87635)<I> [Nose (nasal passage)]</I><BR>
# <P>&nbsp;</P><B>Diagnoses</B><BR><U>Encounter for observation for suspected exposure to other biological agents ruled out</U> - Z03.818<BR>
# <P>&nbsp;</P><B>Procedures</B><BR>HANDLG&amp;/OR CONVEY OF SPEC FOR TR OFFICE TO LAB (CPT-99000), Units: 1.<BR>
# <P>&nbsp;</P><BR><BR><font style='font-family:arial;font-size:10pt;color:green'>Electronically signed by Greene, Lisa , RN. on Monday, July 6, 2020 at 03:05 PM</font>

# %%
df3 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'a CPC Return Patient Note')]

# %%
display(HTML(df3.iloc[871]['SOAPTEXT']))
# Out:
#
#
#
#                                             <p align="center" abp="42122"><strong abp="42123"><font size="4" abp="42124">Carolina Pain Care </font></strong></p>
# <p align="center" abp="42125"><strong abp="42126"></strong>&nbsp;</p>
# <p align="center" abp="42128"><strong abp="42129"><u abp="42130"><font size="3" abp="42131">Return Patient Note</font></u></strong></p>
# <p abp="42132">&nbsp;</p>
# <p abp="42133"><strong abp="42134">Patient Name</strong>: Patient First Name&nbsp; Patient Last Name&nbsp;</p>
# <p abp="42137"><strong abp="42138">Patient DOB</strong>: 03/08/1992&nbsp;</p>
# <p abp="42140"><strong abp="42141">Date</strong>: 04/21/2021 08:00AM&nbsp;</p>
# <p abp="42143">&nbsp;</p>
# <b></b><b>CC:</b> abdomen pain<br><b>HPI</b><br>A 29 year old female patient presents with abdomen pain.  <br> <br>History was provided by the patient.<br>
# <p class="seprator" abp="42154">&nbsp;</p>
# ...

# %%
display(HTML(df3.iloc[779]['SOAPTEXT']))
# Out:
#
#
#
#
#
#                                             <p align="center" abp="42122"><strong abp="42123"><font size="4" abp="42124">Carolina Pain Care </font></strong></p>
# <p align="center" abp="42125"><strong abp="42126"></strong>&nbsp;</p>
# <p align="center" abp="42128"><strong abp="42129"><u abp="42130"><font size="3" abp="42131">Return Patient Note</font></u></strong></p>
# <p abp="42132">&nbsp;</p>
# <p abp="42133"><strong abp="42134">Patient Name</strong>: Patient First Name&nbsp; Patient Last Name&nbsp;</p>
# <p abp="42137"><strong abp="42138">Patient DOB</strong>: 03/10/1972&nbsp;</p>
# <p abp="42140"><strong abp="42141">Date</strong>: 02/11/2022 08:15AM&nbsp;</p>
# <p abp="42143">&nbsp;</p>
# <b></b><b>CC:</b> Lower Back Pain<br><b>HPI</b><br>A 49 year old male patient presents with Lower Back Pain.  <br> <br>History was provided by the patient.<br>
# ...

# %%
display(HTML(df3.iloc[2286]['SOAPTEXT']))
# Out:
# <P align=center><b><FONT size=4>Carolina Pain Care </FONT></b></P>
# <P align=center><b></b>&nbsp;</P>
# <P align=center><b><U><FONT size=3>Return Patient Note</FONT></U></b></P>
# <P>&nbsp;</P>
# <P><b>Patient Name</b>: Jeffery&nbsp; Patient Last Name&nbsp;</P>
# <P><b>Patient DOB</b>: 10/10/1972&nbsp;</P>
# <P><b>Date</b>: 03/07/2018 09:15AM&nbsp;</P>
# <P>&nbsp;</P><B></B><B>CC:</B> Neck Pain<BR><B>HPI: </B><BR>A 45 year old male patient presents with Neck Pain. <BR><BR>History was provided by the patient.<BR>
# <P class=seprator>&nbsp;</P>
# <P class=seprator>He thinks his medication is not helping, but he does not want to stop taking it. He is short of medication today.</P>
# ...

# %%
display(HTML(df3.iloc[2200]['SOAPTEXT']))
# Out:
#
#                                             <p align="center"><strong><font size="4">Carolina Pain Care </font></strong></p>
# <p align="center"><strong></strong>&nbsp;</p>
# <p align="center"><strong><u><font size="3">Return Patient Note</font></u></strong></p>
# <p>&nbsp;</p>
# <p><strong>Patient Name</strong>: Patient First Name&nbsp; Patient Last Name&nbsp;</p>
# <p><strong>Patient DOB</strong>: 08/10/1939&nbsp;</p>
# <p><strong>Date</strong>: 11/26/2019 10:30AM&nbsp;</p>
# <p>&nbsp;</p>
# <b></b><b>CC:</b> Back Pain<br><b>HPI: </b><br>A 80 year old female patient presents with Back Pain.  <br> <br>History was provided by the patient.<br>
# <p class="seprator"><br></p><p class="seprator">Pt. Is about 2 days short on medication. She took extra medicine due to being sore from building an outdoor shelter for her 36 cats. She states she won't be short again. We discussed using a pill organizer.&nbsp;&nbsp;</p>
# <p class="seprator">&nbsp;</p>
# ...

# %%
df4 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'TB Skin Test')]

# %%
display(HTML(df4.iloc[1]['SOAPTEXT']))
# Out:
#
#
#
#                                             <p align="center"><strong><u><font size="4">&nbsp;TB Skin Test</font></u></strong> </p>
# <p align="center">&nbsp;</p>
# <p align="left"><strong><u>Patient Name</u></strong>: TestFirstName&nbsp;TestLastName</p>
# <p align="left"><strong><u>DOB</u></strong>: 07/03/1989</p>
# <p align="left"><strong><u>Sex</u></strong>: female</p>
# <p align="left"><strong><u>Race</u></strong>: White</p>
# <p align="left">&nbsp;</p>
# <p align="left">&nbsp;</p>
# <b>Allergies</b><br>Allergy: NKDA<br>
# <p>&nbsp;<strong></strong>&nbsp;<br>
# </p><div id="2220209386854">
# <table style="BORDER-TOP: #000000 1px solid; BORDER-RIGHT: #000000 1px solid; WIDTH: 500px; BORDER-COLLAPSE: collapse; BORDER-BOTTOM: #000000 1px solid; TEXT-ALIGN: left; BORDER-LEFT: #000000 1px solid; BACKGROUND-COLOR: #ffffff" border="1" &nbsp;="" id="t1">
# <tbody>
# <tr style="HEIGHT: 10px" id="t1r0">
# ...

# %%
display(HTML(df4.iloc[77]['SOAPTEXT']))
# Out:
#
#
#
#
#                                             <p align="center"><strong><font size="3">&nbsp; WILSON COUNTY HEALTH DEPARTMENT</font></strong></p>
# <p align="center"><strong><font size="3">Skin Test</font></strong></p>
# <p align="center"><strong></strong>&nbsp;</p>
# <p><strong></strong>&nbsp;</p>
# ...

# %%
display(HTML(df4.iloc[171]['SOAPTEXT']))
# Out:
# <P align=center><b><U><FONT size=4>TB Skin Test</FONT></U></b> </P>
# <P align=center>&nbsp;</P>
# <P align=left><b><U>Patient Name</U></b>: TestFirstName&nbsp;TestLastName</P>
# <P align=left><b><U>DOB</U></b>: 09/15/1996</P>
# <P align=left><b><U>Sex</U></b>: female</P>
# <P align=left><b><U>Race</U></b>: White</P>
# <P align=left>&nbsp;</P>
# <P align=left>&nbsp;</P><B>Allergies:</B><BR>NKDA<BR>
# <P>&nbsp;</P><B>TB Skin Test:</B><BR>
# <TABLE id=t2 style="BORDER-TOP: gray 1pt solid; BORDER-RIGHT: gray 1pt solid; WIDTH: 98%; BORDER-COLLAPSE: collapse; BORDER-BOTTOM: gray 1pt solid; BORDER-LEFT: gray 1pt solid; layout: fixed" cellSpacing=0 cellPadding=2 border=1>
# <TBODY>
# <TR id=t2r0 class=itemrow>
# <TD id=t2r0c0 style="WORD-WRAP: break-word; WIDTH: 20%; WHITE-SPACE: pre-wrap" bgColor=#ffffe7 align=left><FONT color=#000000 size=2 face=arial>&nbsp;</FONT></TD>
# ...

# %%
display(HTML(df4.iloc[717]['SOAPTEXT']))
# Out:
#                                             <p class="seprator" style="text-align: center;"><font size="4">Cumberland County Public Health Department</font></p><p class="seprator" style="text-align: center;"><font size="4">TB Skin Test Admin/ Read Note</font></p><br><p class="seprator"></p><div id="btn~~20206841s54" onmousedown="onmouserightclick('btn~~20206841s54')" contenteditable="false" style="cursor: pointer; width: 100%;" onclick="clearSelection()" onresizestart="return false;" ondblclick="OnBtn('btn~~20206841s54','Patient/Clinical/Custom_Forms/datPatCustomForm.aspx?')" intform_id="39207" class="btnComponent_Attached" intcomponentrecid="39207" icompid="242600" unselectable="on"><table class="tblButton" cellspacing="0" cellpadding="0" width="100%" border="0"><tbody><tr><td align="left"><font class="Comp_Heading_Attached" id="Comp_Heading" face="arial">State Mandated Questions</font></td></tr><tr class="traDetail_Attached" id="traDetail"><td><label id="lbl" ondrag="vbscript:windo
# ...

# %%
df5 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'WIC Lab')]

# %%
display(HTML(df5.iloc[117]['SOAPTEXT']))
# Out:
# <P align=center><STRONG>WIC Patient</STRONG></P>
# <P align=center>&nbsp;</P>
# <P align=center><STRONG></STRONG>&nbsp;</P>
# <P align=left><STRONG>Patient: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~21553 contentEditable=false style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§"></LABEL>, <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~21554 contentEditable=false style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§"></LABEL></STRONG></P>
# ...

# %%
display(HTML(df5.iloc[717]['SOAPTEXT']))
# Out:
# <P align=center><STRONG>WIC Patient</STRONG></P>
# <P align=center>&nbsp;</P>
# <P align=center><STRONG></STRONG>&nbsp;</P>
# <P align=left><STRONG>Patient: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~21553 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§" j="§"></LABEL>, <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~21554 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§" j="§"></LABEL></STRONG></P>
# ...

# %%
df6 = data[(data['Notetype'] == 'Admit Note') & (data['NoteTemplate'] == 'SCHD A Blank SOAP NOTE')]

# %%
display(HTML(df6.iloc[117]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=4>&nbsp;A BLANK SOAP NOTE<BR></FONT><FONT size=3>Sampson County Health Department</FONT></STRONG></P>
# <P align=center>&nbsp;</P>
# <P>Patient Name: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~3425873 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" j="§" f="§"></LABEL>,&nbsp; <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~3425874 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" j="§" f="§"></LABEL></P>
# ...

# %%
display(HTML(df6.iloc[199]['SOAPTEXT']))
# Out:
# <BUTTON onclick=clearSelection() ondblclick=popupComponent(67,6977,3417192) onmousedown="onmouserightclick('btn~~3417192s67')" id=btn~~3417192s67 class=btnComponent_Attached contentEditable=false style="CURSOR: hand" unselectable="on" ICompID="-4" intComponentRecID="6977" intForm_ID="6977">
# <TABLE class=tblButton cellSpacing=0 cellPadding=0 width="100%" border=0>
# <TBODY>
# <TR>
# <TD align=left><FONT id=Comp_Heading class=Comp_Heading_Attached face=arial>SCHD Problem/Needs List:</FONT></TD></TR>
# <TR id=traDetail class=traDetail_Attached>
# <TD><LABEL onkeypress="return stopDataEntry()" ondblclick="lblDbl_Click('btn~~3417192s67')" oncut=vbscript:window.event.returnvalue=false ondrag=vbscript:window.event.returnvalue=false id=lbl onpaste=vbscript:window.event.returnvalue=false contentEditable=false onkeydown="return stopDataEntry()" ondrop=vbscript:window.event.returnvalue=false><FONT id=Comp_Heading_Detail class=Comp_Heading_Detail face=arial>
# ...

# %%
display(HTML(df6.iloc[177]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=4>&nbsp;A BLANK SOAP NOTE<BR></FONT><FONT size=3>Sampson County Health Department</FONT></STRONG></P>
# <P align=center>&nbsp;</P>
# <P>Patient Name: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~3425873 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" j="§" f="§" jQuery17206407044871353323="77"></LABEL>,&nbsp; <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~3425874 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" j="§" f="§" jQuery17206407044871353323="78"></LABEL></P>
# ...

# %%
display(HTML(df6.iloc[231]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=4>&nbsp;A BLANK SOAP NOTE<BR></FONT><FONT size=3>Sampson County Health Department</FONT></STRONG></P>
# <P align=center>&nbsp;</P>
# <P>Patient Name: <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~3425873 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§" j="§" jQuery17208709358620694879="58"></LABEL>,&nbsp; <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~3425874 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§" j="§" jQuery17208709358620694879="59"></LABEL></P>
# ...

# %%
df7 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'STD Encounter - Form 2808')]

# %%
display(HTML(df7.iloc[117]['SOAPTEXT']))
# Out:
#
#
#
#
#
#
#
#                                             <span id="span_1520536537570"><font size="4"><strong><u><p class="seprator">&nbsp;</p><div id="btn~~20245945s5"><b>Prescription</b><br><u>Valtrex 1 GM Oral Tablet:</u>  0.5 Tablet(s) daily Oral,  Start 01/20/2023,  Qty 45 Tablet(s)  For 90 Day(s)<br></div><p class="seprator"><br></p>STD Encounter - 2808</u></strong></font></span>
# <p><font size="3"><strong></strong></font>&nbsp;</p>
# <div id="btn~~20245854s2"><b>Vital Signs</b><br><b> </b>Weight 171 lbs 2 oz Taken on Jan 20, 2023 at 8:19 AM by Mooe, Kellie CNA<br></div>
# <p>&nbsp;</p>
# <div id="btn~~20245867s51"><b>Allergies</b><br>  Sulfa Antibiotics   (General) <br></div>
# <p>&nbsp;</p>
# <div id="btn~~20245853s1"><b></b><b>HPI</b><br>A 27 year old female patient presents with STD Screening - Symptoms.  <br></div>
# ...

# %%
display(HTML(df7.iloc[1127]['SOAPTEXT']))
# Out:
#
#
#
#
#
#
#
#
#
#
#                                             <p align="center"><strong><u><font size="4">STD Encounter - Form 2808</font></u></strong></p>
# <p align="center">N.C. Department of Health and Human Services</p>
# <p align="center">Office of Public Health Nursing &amp; Professional Development</p>
# <p><strong><u></u></strong>&nbsp;</p>
# ...

# %%
df8 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'Follow Up')]

# %%
display(HTML(df8.iloc[117]['SOAPTEXT']))
# Out:
# <P align=center>&nbsp;</P>
# <P><FONT size=3><FONT size=2>NAME:</FONT> </FONT>Patient First Name&nbsp;Patient Last Name</P>
# <P><FONT size=3><FONT size=2>DATE:</FONT> August 13, 2018</FONT></P>
# <P><FONT size=3><FONT size=2>REFERRING PHYSICIAN:</FONT> &nbsp;</FONT></P>
# <P><FONT size=3><FONT size=2>DOB:</FONT> </FONT>07/22/1978&nbsp;</P>
# <P>&nbsp;</P><B></B><B>CC:</B> ADDICTION<BR><B>HPI: </B><BR>A 40 year old female patient presents with ADDICTION. <BR><BR>In addition she presents with counseling with Dr. Nichols. <BR>
# <P>&nbsp;</P><B>Vital Signs:</B><BR><B></B>Weight 138 lbs Height 5' 1'', BMI 26.07 kg/m sq, Category Overweight, Temp 99.80 F - Oral, Pulse 82 b/m - Regular Sinus Rhythm - Sitting, Respiration 18 b/m - Normal, BP <FONT color=#ff9900>111</FONT>/<FONT color=#ff9900>78 mm/Hg </FONT>- Sitting - Right Arm - Standard Cuff Size - Automatic Recording Taken on Aug 13, 2018 at&nbsp; 3:42 PM by Ms Brown, Shakerra<BR>
# ...

# %%
display(HTML(df8.iloc[135]['SOAPTEXT']))
# Out:
# <P class=seprator>&nbsp;</P><B>Vital Signs:</B><BR><B></B>Weight 132 lbs 4 oz, Height 5' 5.50'', BMI 21.67 kg/m sq, Category Normal Weight, Temp 97.90 F - Oral, Pulse 92 b/m , Respiration 18 b/m, BP <FONT color=red>122</FONT>/<FONT color=red>95 mm/Hg </FONT>- Sitting - Left Arm - Standard Cuff Size SAO2 94% - Resting - Room Air, - Manual Recording Taken on Dec 16, 2019 at 8:43 AM by Ms vicaria, amy<BR>
# <P class=seprator>&nbsp;</P>
# <P align=center>&nbsp;</P>
# <P><FONT size=3><FONT size=2><b>NAME</b>:</FONT> </FONT>Patient First Name&nbsp;Patient Last Name</P>
# <P><FONT size=3><FONT size=2><b>DATE</b>:</FONT> December 16, 2019</FONT></P>
# <P><FONT size=3><FONT size=2><b>REFERRING PHYSICIAN</b>:</FONT> &nbsp;</FONT></P>
# <P><FONT size=3><FONT size=2><b>DOB</b>:</FONT> </FONT>12/23/1990&nbsp;</P>
# <P sizset="0" sizcache0008980945017108332="776"><b></b>&nbsp;</P>
# <P sizset="0" sizcache0008980945017108332="776"><b>SUBJECTIVE</b>:&nbsp;&nbsp;fu cholesterol </P>
# ...

# %%
display(HTML(df8.iloc[254]['SOAPTEXT']))
# Out:
# <P align=center>&nbsp;</P>
# <P><FONT size=3><FONT size=2><b>NAME</b>:</FONT> </FONT>Patient First Name&nbsp;Patient Last Name</P>
# <P><FONT size=3><FONT size=2><b>DATE</b>:</FONT> July 08, 2019</FONT></P>
# <P><FONT size=3><FONT size=2><b>REFERRING PHYSICIAN</b>:</FONT> &nbsp;</FONT></P>
# <P><FONT size=3><FONT size=2><b>DOB</b>:</FONT> </FONT>08/12/1988&nbsp;</P>
# <P sizset="0" sizcache0008980945017108332="776"><b></b>&nbsp;</P>
# <P sizset="0" sizcache0008980945017108332="776"><b>SUBJECTIVE</b>:&nbsp;&nbsp;Patient here for followup</P>
# <P sizset="0" sizcache0008980945017108332="776"><b></b>&nbsp;</P>
# <P sizset="0" sizcache0008980945017108332="776"><b>OBJECTIVE</b>:&nbsp;&nbsp;treatment for addiction concerns&nbsp;</P>
# ...

# %%
display(HTML(df8.iloc[371]['SOAPTEXT']))
# Out:
#
#
#
#                                             <p align="center">&nbsp;</p>
# <p><font size="3"><font size="2"><strong>NAME</strong>:</font> </font>Patient First Name&nbsp;Patient Last Name</p>
# <p><font size="3"><font size="2"><strong>DATE</strong>:</font> September 18, 2018</font></p>
# <p><font size="3"><font size="2"><strong>REFERRING PHYSICIAN</strong>:</font> &nbsp;</font></p>
# <p><font size="3"><font size="2"><strong>DOB</strong>:</font> </font>10/06/1959&nbsp;</p>
# <p sizcache0008980945017108332="776" sizset="0"><strong></strong>&nbsp;</p>
# <p sizcache0008980945017108332="776" sizset="0"><strong>SUBJECTIVE</strong>:&nbsp;&nbsp;patient here for medication refill</p>
# <p sizcache0008980945017108332="776" sizset="0"><strong></strong>&nbsp;</p>
# <p sizcache0008980945017108332="776" sizset="0"><strong>OBJECTIVE</strong>:&nbsp;&nbsp;patient here for medication refill&nbsp;</p>
# <p sizcache0008980945017108332="776" sizset="0">&nbsp;</p>
# ...

# %%
df9 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'APC - Sick Visit Note')]

# %%
df9.iloc[117]['SOAPTEXT']
# Out:
# '<P align=center><FONT size=4><STRONG>ADULT HEALTH PRIMARY CARE VISIT NOTE</STRONG></FONT></P>\r\n<P align=left><STRONG><U></U></STRONG>&nbsp;</P>\r\n<P align=left><FONT size=3><STRONG><U>Visit Date:</U></STRONG> <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~316~dum~184917 contentEditable=false style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" type=button value="September 17, 2015" unselectable="on" f="§"></LABEL></FONT></P>\r\n<P>&nbsp;</P>\r\n<P><BUTTON onclick=clearSelection() ondblclick="OnBtn(\'btn~~615569s54\',\'../../Custom_Forms/datPatCustomForm.aspx?\')" onresizestart="return false;" onmousedown="onmouserightclick(\'btn~~615569s54\')" id=btn~~615569s54 class=btnComponent_Attached contentEditable=false style="CURSOR: hand; WIDTH: 100%" unselectable="on" intComponentRecID="85730" iCompID="438958" intForm_ID="85730">\r\n<TABLE class=tblButton cellSpacing=0 cellPadding=0 width="100
# ...

# %%
display(HTML(df9.iloc[145]['SOAPTEXT']))
# Out:
# <P align=center><FONT size=4><STRONG>ADULT HEALTH PRIMARY CARE VISIT NOTE</STRONG></FONT></P>
# <P align=left><STRONG><U></U></STRONG>&nbsp;</P>
# <P align=left><FONT size=3><STRONG><U>Visit Date:</U></STRONG> <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~316~dum~184917 contentEditable=false style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" type=button value="February 02, 2016" unselectable="on" f="§"></LABEL></FONT></P>
# <P>&nbsp;</P>
# <P><BUTTON onclick=clearSelection() ondblclick="OnBtn('btn~~750021s54','../../Custom_Forms/datPatCustomForm.aspx?')" onresizestart="return false;" onmousedown="onmouserightclick('btn~~750021s54')" id=btn~~750021s54 class=btnComponent_Attached contentEditable=false style="CURSOR: hand; WIDTH: 100%" unselectable="on" intComponentRecID="104068" intForm_ID="104068" iCompID="557466">
# ...

# %%
df10 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'Maternal Flow')]

# %%
display(HTML(df10.iloc[117]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><U></U></STRONG>&nbsp;</P>
# <P align=center><STRONG><U><FONT size=3>MATERNAL FLOW</FONT></U></STRONG></P>
# <P align=center>N.C. Department of Health and Human Services</P>
# <P align=center>Division of Public Health</P>
# <P align=center>Women's and Children's Health Section</P>
# <P align=center><STRONG></STRONG>&nbsp;</P>
# <P align=left><STRONG><U></U></STRONG>&nbsp;</P>
# <P align=left><U><FONT size=3><STRONG>Patient Demographics</STRONG>:</FONT></U></P>
# <P align=left><STRONG>Age:</STRONG> <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~15~dum~9754 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value="18 Y" unselectable="on" j="§" f="§"></LABEL></P>
# ...

# %%
df11 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'Immunization-Flu Note')]

# %%
display(HTML(df11.iloc[117]['SOAPTEXT']))
# Out:
#                                             <p align="center"><strong><font size="3">Brunswick County Health Services</font></strong></p>
# <p align="center"><strong><font size="3">Flu Immunization Clinic</font></strong></p>
# <p align="center"><strong></strong>&nbsp;</p>
# <p align="left">
# <div id="172014132220352">
# <table width="498" align="left" id="t0" style="width: 498px; height: 87px; border-collapse: collapse;" bgcolor="#ffffff" border="1">
# <tbody>
# <tr height="10" id="t0r0">
# <td width="250" id="t0r0c0">&nbsp;Last Name</td>
# <td width="250" id="t0r0c1">&nbsp;<label contenteditable="false"><input id="fld~~4~dum~102375" style="border: 0px currentColor; border-image: none; text-align: left; background-color: rgb(255, 255, 255);" contenteditable="false" onclick="clearSelection()" type="button" value="TestLastName" unselectable="on" f="§" j="§"></label></td></tr>
# <tr height="10" id="t0r1">
# <td width="250" id="t0r1c0">&nbsp;First Name</td>
# ...

# %%
display(HTML(df11.iloc[175]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>Brunswick County Health Services</FONT></STRONG></P>
# <P align=center><STRONG><FONT size=3>Flu Immunization Clinic</FONT></STRONG></P>
# <P align=center><STRONG></STRONG>&nbsp;</P>
# <P align=left>
# <DIV id=172014132220352>
# <TABLE id=t0 style="HEIGHT: 87px; WIDTH: 498px; BORDER-COLLAPSE: collapse" width=498 align=left bgColor=#ffffff border=1>
# <TBODY>
# <TR id=t0r0 height=10>
# <TD id=t0r0c0 width=250>&nbsp;Last Name</TD>
# <TD id=t0r0c1 width=250>&nbsp;<LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~102375 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" j="§" f="§"></LABEL></TD></TR>
# <TR id=t0r1 height=10>
# <TD id=t0r1c0 width=250>&nbsp;First Name</TD>
# ...

# %%
display(HTML(df11.iloc[155]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>Brunswick County Health Services</FONT></STRONG></P>
# <P align=center><STRONG><FONT size=3>Immunization Clinic</FONT></STRONG></P>
# <P align=center><STRONG></STRONG>&nbsp;</P>
# <P align=left>
# <DIV id=172014132220352>
# <TABLE id=t0 style="HEIGHT: 87px; WIDTH: 498px; BORDER-COLLAPSE: collapse" width=498 align=left bgColor=#ffffff border=1>
# <TBODY>
# <TR id=t0r0 height=10>
# <TD id=t0r0c0 width=250>&nbsp;Last Name</TD>
# <TD id=t0r0c1 width=250>&nbsp;<LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~102375 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§"></LABEL></TD></TR>
# <TR id=t0r1 height=10>
# <TD id=t0r1c0 width=250>&nbsp;First Name</TD>
# ...

# %%
display(HTML(df11.iloc[271]['SOAPTEXT']))
# Out:
#                                             <p align="center"><strong><font size="3">Brunswick County Health Services</font></strong></p>
# <p align="center"><strong><font size="3">Flu Immunization Clinic</font></strong></p>
# <p align="center"><strong></strong>&nbsp;</p>
# <p align="left">
# </p><div id="172014132220352">
# <table width="498" align="left" id="t0" style="HEIGHT: 87px; WIDTH: 498px; BORDER-COLLAPSE: collapse" bgcolor="#ffffff" border="1">
# <tbody>
# <tr height="10" id="t0r0">
# <td width="250" id="t0r0c0">&nbsp;Last Name</td>
# <td width="250" id="t0r0c1">&nbsp;<label contenteditable="false"><input id="fld~~4~dum~102375" style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" contenteditable="false" onclick="clearSelection()" type="button" value="TestLastName" unselectable="on" j="§" f="§"></label></td></tr>
# <tr height="10" id="t0r1">
# <td width="250" id="t0r1c0">&nbsp;First Name</td>
# ...

# %%
display(HTML(df11.iloc[219]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>Brunswick County Health Services</FONT></STRONG></P>
# <P align=center><STRONG><FONT size=3>Immunization Clinic</FONT></STRONG></P>
# <P align=center><STRONG><FONT size=3></FONT></STRONG>&nbsp;</P>
# <P align=left>
# <DIV id=172014132220352>
# <TABLE style="WIDTH: 498px; BORDER-COLLAPSE: collapse; HEIGHT: 87px" id=t0 border=1 width=498 bgColor=#ffffff align=left>
# <TBODY>
# <TR id=t0r0 height=10>
# <TD id=t0r0c0 width=250>&nbsp;Last Name</TD>
# <TD id=t0r0c1 width=250>&nbsp;<LABEL contentEditable=false><INPUT style="BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff; BORDER-TOP: 0px; BORDER-RIGHT: 0px" id=fld~~4~dum~102375 contentEditable=false onclick=clearSelection() value=TestLastName type=button unselectable="on" f="§"></LABEL></TD></TR>
# <TR id=t0r1 height=10>
# <TD id=t0r1c0 width=250>&nbsp;First Name</TD>
# ...

# %%
display(HTML(df11.iloc[419]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>Brunswick County Health Services</FONT></STRONG></P>
# <P align=center><STRONG><FONT size=3>Flu Immunization Clinic</FONT></STRONG></P>
# <P align=center><STRONG></STRONG>&nbsp;</P>
# <P align=left>
# <DIV id=172014132220352>
# <TABLE id=t0 style="HEIGHT: 87px; WIDTH: 498px; BORDER-COLLAPSE: collapse" width=498 align=left bgColor=#ffffff border=1>
# <TBODY>
# <TR id=t0r0 height=10>
# <TD id=t0r0c0 width=250>&nbsp;Last Name</TD>
# <TD id=t0r0c1 width=250>&nbsp;<LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~102375 contentEditable=false style="BORDER-LEFT-WIDTH: 0px; BORDER-RIGHT-WIDTH: 0px; BORDER-BOTTOM-WIDTH: 0px; TEXT-ALIGN: left; BORDER-TOP-WIDTH: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" j="§" f="§"></LABEL></TD></TR>
# <TR id=t0r1 height=10>
# <TD id=t0r1c0 width=250>&nbsp;First Name</TD>
# ...

# %%
df12 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'TB Skin Test Reading')]

# %%
display(HTML(df12.iloc[117]['SOAPTEXT']))
# Out:
#                                             <p align="center"><strong><u><font size="4">TB Skin Test Reading</font></u></strong> </p>
# <p align="center">&nbsp;</p>
# <p align="left"><strong><u>Patient Name</u></strong>: <label contenteditable="false"><input id="fld~~5~dum~3319620" style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" contenteditable="false" type="button" value="TestFirstName" j="§" unselectable="on" onclick="clearSelection()" f="§"></label>&nbsp;<label contenteditable="false"><input id="fld~~4~dum~3319621" style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" contenteditable="false" type="button" value="TestLastName" j="§" unselectable="on" onclick="clearSelection()" f="§"></label></p>
# ...

# %%
display(HTML(df12.iloc[175]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>WILSON COUNTY HEALTH DEPARTMENT</FONT></STRONG></P>
# <P align=center><STRONG><FONT size=3>TB Skin Test Reading</FONT></STRONG></P>
# <P>&nbsp;</P>
# <P><LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~4~dum~68015 contentEditable=false style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestLastName unselectable="on" f="§"></LABEL>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <LABEL contentEditable=false><INPUT onclick=clearSelection() id=fld~~5~dum~68016 contentEditable=false style="BORDER-TOP: 0px; BORDER-RIGHT: 0px; BORDER-BOTTOM: 0px; TEXT-ALIGN: left; BORDER-LEFT: 0px; BACKGROUND-COLOR: #ffffff" type=button value=TestFirstName unselectable="on" f="§"></LABEL></P>
# <P>&nbsp;</P>
# <P><STRONG></STRONG>&nbsp;</P>
# ...

# %%
df13 = data[(data['Notetype'] == 'Progress Note') & (data['NoteTemplate'] == 'IM/TST Encounter-HCDPH')]
display(HTML(df13.iloc[117]['SOAPTEXT']))
# Out:
#
#                                             <p align="center"><strong><font size="3">Immunization/TB Skin Test Encounter&nbsp;</font></strong></p>
# <div onclick="clearSelection()" ondblclick="OnBtn('btn~~7968328s51','Patient/Clinical/Patient_Data/Allergy_List/lstAllergyList.aspx?')" onresizestart="return false;" onmousedown="onmouserightclick('btn~~7968328s51')" id="btn~~7968328s51" class="btnComponent_Attached" contenteditable="false" style="cursor: pointer; width: 100%;" intcomponentrecid="202095" icompid="1395848" unselectable="on">
# <table class="tblButton" cellspacing="0" cellpadding="0" width="100%" border="0">
# <tbody>
# <tr>
# <td align="left"><font id="Comp_Heading" class="Comp_Heading_Attached" face="arial">Allergies</font></td></tr>
# <tr id="traDetail" class="traDetail_Attached">
# ...

# %%
display(HTML(df13.iloc[175]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>Immunization/TB Skin Test Encounter&nbsp;</FONT></STRONG></P>
# <DIV onclick=clearSelection() ondblclick="OnBtn('btn~~4781830s51','Patient/Clinical/Patient_Data/Allergy_List/lstAllergyList.aspx?')" onresizestart="return false;" onmousedown="onmouserightclick('btn~~4781830s51')" id=btn~~4781830s51 class=btnComponent_Attached contentEditable=false style="CURSOR: pointer; WIDTH: 100%" unselectable="on" ICompID="668123" intComponentRecID="81770" jQuery172006291240821788046="47">
# <TABLE class=tblButton cellSpacing=0 cellPadding=0 width="100%" border=0>
# <TBODY>
# <TR>
# <TD align=left><FONT id=Comp_Heading class=Comp_Heading_Attached face=arial>Allergies:</FONT></TD></TR>
# <TR id=traDetail class=traDetail_Attached>
# ...

# %%
display(HTML(df13.iloc[275]['SOAPTEXT']))
# Out:
# <P align=center><STRONG><FONT size=3>Immunization/TB Skin Test Encounter&nbsp;</FONT></STRONG></P>
# <DIV onclick=clearSelection() ondblclick=popupComponent(51,140008,7377822) onmousedown="onmouserightclick('btn~~7377822s51')" id=btn~~7377822s51 class=btnComponent_Attached contentEditable=false style="CURSOR: pointer" unselectable="on" ICompID="982547" intComponentRecID="140008" jQuery17208830357765812322="46">
# <TABLE class=tblButton style="WIDTH: 100%" cellSpacing=0 cellPadding=0 border=0>
# <TBODY>
# <TR>
# <TD style="TEXT-ALIGN: left"><FONT id=Comp_Heading class=Comp_Heading_Attached face=arial>Allergies</FONT></TD></TR>
# <TR id=traDetail class=traDetail_Attached>
# ...
